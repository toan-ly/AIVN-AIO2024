# %%
# Download image
# !gdown 1i9dqan21DjQoG5Q_VEvm0LrVwAlXD0vB
# !mkdir data
# !mv dog.jpeg data
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1i9dqan21DjQoG5Q_VEvm0LrVwAlXD0vB
# To: /Users/toanne/Desktop/AIO/Main Course/AIVN-AIO2024/module2/dog.jpeg
# 100%|██████████████████████████████████████| 33.7k/33.7k [00:00<00:00, 46.0MB/s]
# mkdir: data: File exists

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

def convert_to_grayscale(img: np.ndarray, method: str) -> np.ndarray:
    if len(img.shape) != 3 or img.shape[2] != 3:
        raise ValueError("Input image must have 3 color channels (RGB).")

    img = img.copy()
    method = method.lower()

    if method == 'lightness':
        return 0.5 * np.max(img, axis=-1) + 0.5 * np.min(img, axis=-1)
    elif method == 'average':
        # return 0.33 * img[..., 0] + 0.33*img[..., 1] + 0.33*img[..., 2]
        return np.mean(img, axis=-1)
    elif method == 'luminosity':
        luminosity_values = [0.21, 0.72, 0.07]
        return np.dot(img, luminosity_values)
    else:
        raise ValueError("Invalid method. Choose from 'lightness', 'average', or 'luminosity'.")

def plot_images(orig_img: np.ndarray, gray_img: np.ndarray, method: str) -> None:
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    axes[0].imshow(orig_img)
    axes[0].set_title('Original Image')
    axes[0].axis('off')

    axes[1].imshow(gray_img, cmap='gray')
    axes[1].set_title(f'Grayscale Image ({method})')
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
img = mpimg.imread('data/dog.jpeg')

method = 'Lightness'
img_gray = convert_to_grayscale(img, method=method)
print(img_gray[0, 0])
plot_images(img, img_gray, method=method)
# Out:
# 102.5

# %%
method = 'Average'
img_gray = convert_to_grayscale(img, method=method)
print(img_gray[0, 0])
plot_images(img, img_gray, method=method)
# Out:
# 107.66666666666667

# %%
method = 'Luminosity'
img_gray = convert_to_grayscale(img, method=method)
print(img_gray[0, 0])
plot_images(img, img_gray, method=method)
# Out:
# 126.22999999999999

# %%
img = mpimg.imread('data/cute_doraemon.jpg')

img_gray = convert_to_grayscale(img, 'lightness')
plot_images(img, img_gray, 'lightness')

img_gray = convert_to_grayscale(img, 'average')
plot_images(img, img_gray, 'average')

img_gray = convert_to_grayscale(img, 'luminosity')
plot_images(img, img_gray, 'luminosity')
