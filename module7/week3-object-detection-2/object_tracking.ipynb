# %%
# !pip install collection
# !pip install ultralytics

# %%
from collections import defaultdict
import cv2
import numpy as np
from ultralytics import YOLO

# %%
model = YOLO("yolo11l.pt")

video_path = "vietnam.mp4"
cap = cv2.VideoCapture(video_path)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l.pt to 'yolo11l.pt'...
# 100%|██████████| 49.0M/49.0M [00:00<00:00, 194MB/s]

# %%
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Create VideoWriter object
video_name = video_path.split("/")[-1]
output_path = f"run/{video_name.split('.')[0]}_tracked.mp4"
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# %%
# Store the track history
track_history = defaultdict(lambda: [])

# Loop through the video frames
while cap.isOpened():
    success, frame = cap.read()

    if success:
        results = model.track(frame, persist=True, show=False)
        boxes = results[0].boxes.xywh.cpu()
        try:
            track_ids = results[0].boxes.id
            if track_ids is not None:
                track_ids = track_ids.int().cpu().tolist()
            else:
                track_ids = [] # No tracks found in this frame
        except AttributeError:
            track_ids = [] # Handle case where tracking fails

        # Visualize a result on the frame
        annotated_frame = results[0].plot()

        # Plot the tracks only if we have valid tracking data
        if track_ids:
            for box, track_id in zip(boxes, track_ids):
                x, y, w, h = box
                track = track_history[track_id]
                track.append((float(x), float(y)))

                if len(track) > 120:
                    track.pop(0)

                # Draw the tracking lines
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                cv2.polylines(
                    annotated_frame,
                    [points],
                    isClosed=False,
                    color=(230, 230, 230),
                    thickness=4,
                )

        # Write the frame to output video
        out.write(annotated_frame)
    else:
        # Break the loop if the end of the video is reached
        break

cap.release()
out.release()
print(f"Video has been saved to {output_path}")
# Out:
# 0: 384x640 19 persons, 6 cars, 26 motorcycles, 1 bus, 2 trucks, 1104.1ms
# Speed: 5.7ms preprocess, 1104.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 5 cars, 25 motorcycles, 1 bus, 3 trucks, 1009.9ms
# Speed: 4.0ms preprocess, 1009.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 5 cars, 25 motorcycles, 1 bus, 4 trucks, 957.4ms
# Speed: 4.6ms preprocess, 957.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 5 cars, 25 motorcycles, 1 bus, 4 trucks, 1 backpack, 984.3ms
# Speed: 4.6ms preprocess, 984.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 5 cars, 25 motorcycles, 1 bus, 4 trucks, 1 backpack, 979.3ms
# Speed: 4.5ms preprocess, 979.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 5 cars, 27 motorcycles, 1 bus, 4 trucks, 1 backpack, 978.8ms
# Speed: 4.0ms preprocess, 978.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 5 cars, 27 motorcycles, 2 buss, 3 trucks, 1 backpack, 991.8ms
# Speed: 4.1ms preprocess, 991.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 6 cars, 27 motorcycles, 2 buss, 3 trucks, 1 backpack, 965.5ms
# Speed: 4.0ms preprocess, 965.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 5 cars, 27 motorcycles, 2 buss, 3 trucks, 1 backpack, 975.2ms
# Speed: 4.0ms preprocess, 975.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 6 cars, 26 motorcycles, 2 buss, 2 trucks, 1 backpack, 1296.8ms
# Speed: 4.7ms preprocess, 1296.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 7 cars, 26 motorcycles, 3 buss, 2 trucks, 1 backpack, 1572.0ms
# Speed: 4.4ms preprocess, 1572.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 7 cars, 26 motorcycles, 3 buss, 2 trucks, 1 backpack, 1034.2ms
# Speed: 4.4ms preprocess, 1034.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 7 cars, 27 motorcycles, 3 buss, 2 trucks, 1 backpack, 971.0ms
# Speed: 4.3ms preprocess, 971.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 7 cars, 27 motorcycles, 3 buss, 2 trucks, 1 backpack, 964.0ms
# Speed: 4.3ms preprocess, 964.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 7 cars, 26 motorcycles, 3 buss, 2 trucks, 1 backpack, 978.8ms
# Speed: 4.6ms preprocess, 978.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 7 cars, 26 motorcycles, 3 buss, 2 trucks, 1 backpack, 971.0ms
# Speed: 4.6ms preprocess, 971.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 7 cars, 26 motorcycles, 3 buss, 2 trucks, 1 backpack, 972.8ms
# Speed: 4.1ms preprocess, 972.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 7 cars, 26 motorcycles, 3 buss, 2 trucks, 1 backpack, 964.6ms
# Speed: 4.1ms preprocess, 964.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 7 cars, 25 motorcycles, 2 buss, 1 truck, 1 backpack, 965.1ms
# Speed: 4.1ms preprocess, 965.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 7 cars, 25 motorcycles, 3 buss,
3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 cars, 27 motorcycles, 1 bus, 2 trucks, 2 traffic lights, 1 backpack, 1556.2ms
# Speed: 4.2ms preprocess, 1556.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 cars, 27 motorcycles, 1 bus, 2 trucks, 2 traffic lights, 1 backpack, 1248.2ms
# Speed: 4.2ms preprocess, 1248.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 cars, 26 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 970.8ms
# Speed: 8.7ms preprocess, 970.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 bicycle, 6 cars, 26 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 986.7ms
# Speed: 5.0ms preprocess, 986.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 bicycle, 6 cars, 27 motorcycles, 1 bus, 3 trucks, 1 traffic light, 1 backpack, 985.6ms
# Speed: 4.0ms preprocess, 985.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 bicycle, 7 cars, 27 motorcycles, 1 truck, 1 traffic light, 1 backpack, 961.3ms
# Speed: 4.1ms preprocess, 961.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 bicycle, 7 cars, 27 motorcycles, 1 bus, 1 truck, 1 traffic light, 1 backpack, 1005.4ms
# Speed: 4.2ms preprocess, 1005.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 bicycle, 7 cars, 27 motorcycles, 1 bus, 1 truck, 1 traffic light, 1 backpack, 1250.9ms
# Speed: 4.9ms preprocess, 1250.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 7 cars, 27 motorcycles, 1 bus, 1 truck, 1 traffic light, 1 backpack, 973.7ms
# Speed: 4.7ms preprocess, 973.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 6 cars, 26 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1199.9ms
# Speed: 6.3ms preprocess, 1199.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 bicycle, 6 cars, 25 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1476.5ms
# Speed: 4.4ms preprocess, 1476.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 bicycle, 6 cars, 24 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1594.8ms
# Speed: 4.4ms preprocess, 1594.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 bicycle, 6 cars, 24 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1339.9ms
# Speed: 4.2ms preprocess, 1339.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 6 cars, 25 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1358.6ms
# Speed: 4.3ms preprocess, 1358.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 6 cars, 23 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1105.8ms
# Speed: 4.2ms preprocess, 1105.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 bicycle, 6 cars, 23 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1168.2ms
# Speed: 4.1ms preprocess, 1168.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 bicycle, 6 cars, 24 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1293.7ms
# Speed: 5.2ms preprocess, 1293.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 bicycle, 6 cars, 25 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1 backpack, 1143.1ms
# Speed: 6.0ms preprocess, 1143.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 6 cars, 25 motorcycles, 2 buss, 2 trucks, 1 traffic light, 1 backpack, 1190.0ms
# Speed: 4.1ms preprocess, 1190.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 6 cars, 25 motorcycles, 1 bus, 1 truck, 1 traffic light, 1 backpack, 2013.6ms
# Speed: 5.4ms preprocess, 2013.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 6 cars, 24 motorcycles, 1 bus, 2 trucks, 1 traffic light, 1660.0ms
# Speed: 4.3ms preprocess, 1660.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 7 cars, 24 motorcycles, 1 bus, 1 truck, 1022.0ms
# Speed: 5.8ms preprocess, 1022.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 26 motorcycles, 1 bus, 1 truck, 1224.0ms
# Speed: 4.2ms preprocess, 1224.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 26 motorcycles, 1 bus, 1 truck, 1166.1ms
# Speed: 4.2ms preprocess, 1166.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 7 cars, 26 motorcycles, 1 bus, 1 truck, 1 backpack, 1166.7ms
# Speed: 5.7ms preprocess, 1166.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 7 cars, 28 motorcycles, 1 bus, 1 truck, 1 backpack, 1015.2ms
# Speed: 6.3ms preprocess, 1015.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 6 cars, 28 motorcycles, 1 bus, 2 trucks, 1 backpack, 1041.2ms
# Speed: 4.1ms preprocess, 1041.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 6 cars, 27 motorcycles, 2 buss, 2 trucks, 1 backpack, 1155.3ms
# Speed: 5.7ms preprocess, 1155.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 7 cars, 29 motorcycles, 1 bus, 1 truck, 1 backpack, 1240.7ms
# Speed: 4.3ms preprocess, 1240.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 7 cars, 29 motorcycles, 1 bus, 1 truck, 1 backpack, 1563.8ms
# Speed: 4.3ms preprocess, 1563.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 7 cars, 29 motorcycles, 1 bus, 1 truck, 1 backpack, 1107.2ms
# Speed: 9.3ms preprocess, 1107.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 7 cars, 30 motorcycles, 1 bus, 1 truck, 1 backpack, 969.7ms
# Speed: 4.8ms preprocess, 969.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 7 cars, 30 motorcycles, 1 bus, 1 truck, 1 backpack, 1155.7ms
# Speed: 4.6ms preprocess, 1155.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 bicycle, 7 cars, 30 motorcycles, 1 bus, 1 truck, 1 backpack, 987.5ms
# Speed: 4.1ms preprocess, 987.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 bicycle, 7 cars, 30 motorcycles, 1 bus, 1 truck, 1 backpack, 1158.1ms
# Speed: 5.1ms preprocess, 1158.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 7 cars, 29 motorcycles, 1 bus, 1 truck, 1 backpack, 1101.8ms
# Speed: 4.0ms preprocess, 1101.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 bicycle, 7 cars, 28 motorcycles, 1 bus, 1 truck,
1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 8 cars, 24 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1038.4ms
# Speed: 4.0ms preprocess, 1038.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 8 cars, 23 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1015.1ms
# Speed: 4.2ms preprocess, 1015.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 8 cars, 23 motorcycles, 1 bus, 3 trucks, 1 potted plant, 999.0ms
# Speed: 4.1ms preprocess, 999.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 8 cars, 23 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1008.8ms
# Speed: 4.2ms preprocess, 1008.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 6 cars, 23 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1026.0ms
# Speed: 5.5ms preprocess, 1026.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 7 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1039.8ms
# Speed: 4.1ms preprocess, 1039.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 6 cars, 23 motorcycles, 1 bus, 3 trucks, 1 potted plant, 985.9ms
# Speed: 5.1ms preprocess, 985.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 6 cars, 25 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1276.9ms
# Speed: 4.1ms preprocess, 1276.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 6 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1630.5ms
# Speed: 4.3ms preprocess, 1630.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 7 cars, 21 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1053.6ms
# Speed: 4.3ms preprocess, 1053.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 7 cars, 22 motorcycles, 1 bus, 3 trucks, 1 potted plant, 999.2ms
# Speed: 8.9ms preprocess, 999.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 7 cars, 22 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1005.9ms
# Speed: 4.4ms preprocess, 1005.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 7 cars, 22 motorcycles, 2 buss, 2 trucks, 1 potted plant, 1056.0ms
# Speed: 5.3ms preprocess, 1056.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 7 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1016.0ms
# Speed: 4.0ms preprocess, 1016.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 7 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1019.2ms
# Speed: 4.0ms preprocess, 1019.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 7 cars, 22 motorcycles, 1 bus, 3 trucks, 1 potted plant, 994.0ms
# Speed: 4.3ms preprocess, 994.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 24 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1008.0ms
# Speed: 3.9ms preprocess, 1008.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 24 motorcycles, 1 bus, 3 trucks, 1 potted plant, 997.5ms
# Speed: 4.2ms preprocess, 997.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 6 cars, 24 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1505.8ms
# Speed: 4.0ms preprocess, 1505.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 6 cars, 25 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1481.8ms
# Speed: 5.8ms preprocess, 1481.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 6 cars, 25 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1003.3ms
# Speed: 4.7ms preprocess, 1003.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 6 cars, 25 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1014.5ms
# Speed: 5.7ms preprocess, 1014.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 7 cars, 24 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1028.8ms
# Speed: 5.1ms preprocess, 1028.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 cars, 24 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1002.7ms
# Speed: 6.1ms preprocess, 1002.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 cars, 23 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1046.5ms
# Speed: 4.4ms preprocess, 1046.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 8 cars, 23 motorcycles, 1 bus, 3 trucks, 1 potted plant, 1018.6ms
# Speed: 6.6ms preprocess, 1018.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 8 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 998.0ms
# Speed: 4.6ms preprocess, 998.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 977.2ms
# Speed: 4.2ms preprocess, 977.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 cars, 21 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1210.2ms
# Speed: 6.1ms preprocess, 1210.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 6 cars, 21 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1575.4ms
# Speed: 5.6ms preprocess, 1575.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 7 cars, 21 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1232.8ms
# Speed: 4.8ms preprocess, 1232.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 8 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 973.2ms
# Speed: 3.9ms preprocess, 973.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1002.1ms
# Speed: 5.4ms preprocess, 1002.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 23 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1035.2ms
# Speed: 4.1ms preprocess, 1035.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 24 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1028.1ms
# Speed: 4.6ms preprocess, 1028.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 23 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1013.2ms
# Speed: 4.0ms preprocess, 1013.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1061.1ms
# Speed: 4.0ms preprocess, 1061.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1038.3ms
# Speed: 4.1ms preprocess, 1038.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 7 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1009.5ms
# Speed: 3.9ms preprocess, 1009.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 7 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1460.7ms
# Speed: 5.4ms preprocess, 1460.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 7 cars, 22 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1594.4ms
# Speed: 4.4ms preprocess, 1594.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 7 cars, 21 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1049.6ms
# Speed: 6.7ms preprocess, 1049.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 7 cars, 21 motorcycles, 1 bus, 2 trucks, 1 potted plant, 1023.8ms
# Speed: 5.6ms preprocess, 1023.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Video has been saved to run/vietnam_tracked.mp4

# %% [markdown]
# # Optimize Version

# %%
# !pip install loguru

# %%
import argparse
from collections import defaultdict
import cv2
import numpy as np
from tqdm import tqdm
from ultralytics import YOLO
from loguru import logger

# %%
def load_config():
    """Load and return configuration settings"""
    return {
        "model_path": "yolo11x.pt",
        "track_history_length": 120,
        "batch_size": 64,
        "line_thickness": 4,
        "track_color": (230, 230, 230),
    }


def initialize_video(video_path):
    """Initialize video capture and writer objects"""
    cap = cv2.VideoCapture(video_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    video_name = video_path.split("/")[-1]
    output_path = f"run/{video_name.split('.')[0]}_tracked.mp4"
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    return cap, out, output_path, fps

# %%
def update_track_history(track_history, last_seen, track_ids, frame_count, batch_size, frame_idx, history_length):
    """Update tracking history and remove old tracks"""
    current_tracks = set(track_ids)
    for track_id in list(track_history.keys()):
        if track_id in current_tracks:
            last_seen[track_id] = frame_count - (batch_size - frame_idx - 1)
        elif frame_count - last_seen[track_id] > history_length:
            del track_history[track_id]
            del last_seen[track_id]

# %%
def draw_tracks(frame, boxes, track_ids, track_history, config):
    """Draw tracking lines on frame"""
    if not track_ids:
        return frame

    for box, track_id in zip(boxes, track_ids):
        x, y, w, h = box
        track = track_history[track_id]
        track.append((float(x), float(y)))
        if len(track) > config["track_history_length"]:
            track.pop(0)

        points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
        cv2.polylines(
            frame,
            [points],
            isClosed=False,
            color=config["track_color"],
            thickness=config["line_thickness"],
        )
    return frame

# %%
def process_batch(model, batch_frames, track_history, last_seen, frame_count, config):
    """Process a batch of frames through YOLO model"""
    results = model.track(
        batch_frames,
        persist=True,
        tracker="botsort.yaml",
        show=False,
        verbose=False,
        iou=0.5,
    )

    processed_frames = []
    for frame_idx, result in enumerate(results):
        boxes = result.boxes.xywh.cpu()
        track_ids = (
            result.boxes.id.int().cpu().tolist() if result.boxes.id is not None else []
        )

        update_track_history(
            track_history,
            last_seen,
            track_ids,
            frame_count,
            len(batch_frames),
            frame_idx,
            config["track_history_length"],
        )

        annotated_frame = result.plot(font_size=4, line_width=2)
        annotated_frame = draw_tracks(
            annotated_frame, boxes, track_ids, track_history, config
        )
        processed_frames.append(annotated_frame)

    return processed_frames

# %%
def main(video_path):
    """Main function to process video"""
    CONFIG = load_config()
    model = YOLO(CONFIG.get("model_path", "yolo11x.pt"))

    cap, out, output_path, fps = initialize_video(video_path)
    track_history = defaultdict(lambda: [])
    last_seen = defaultdict(int)

    # Calculate frames for 3 seconds
    frames_to_process = int(fps * 3)

    with tqdm(
        total=frames_to_process,
        desc="Processing frames",
        colour="green",
    ) as pbar:
        frame_count = 0
        batch_frames = []

        while cap.isOpened() and frame_count < frames_to_process:
            success, frame = cap.read()
            if not success:
                break

            frame_count += 1
            batch_frames.append(frame)

            if (
                len(batch_frames) == CONFIG["batch_size"]
                or frame_count == frames_to_process
            ):
                try:
                    processed_frames = process_batch(
                        model,
                        batch_frames,
                        track_history,
                        last_seen,
                        frame_count,
                        CONFIG,
                    )
                    for frame in processed_frames:
                        out.write(frame)
                        pbar.update(1)
                    batch_frames = []

                except Exception as e:
                    logger.error(
                        f"Error processing frames {frame_count - len(batch_frames) + 1} to {frame_count}: {str(e)}"
                    )
                    batch_frames = []
                    continue

    try:
        cap.release()
        out.release()
        cv2.destroyAllWindows()
    except Exception as e:
        logger.error(f"Error during cleanup: {str(e)}")

    logger.info(f"\nVideo has been saved to {output_path}")

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--video-path", type=str, default="samples/vietnam-2.mp4")
    args = parser.parse_args()

    main(args.video_path)

    video_path = "samples/vietnam-2.mp4"
    main(video_path)
