# %%
# !gdown --id 178YSDYmlRh54IcxStgYA3UyKFRM9-3DO
# !unzip dataset.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=178YSDYmlRh54IcxStgYA3UyKFRM9-3DO
# To: /content/dataset.zip
# 100% 2.35M/2.35M [00:00<00:00, 31.4MB/s]
# Archive:  dataset.zip
#    creating: dataset/
#   inflating: dataset/weatherHistory.csv

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
import torch
import torch.nn as nn

seed = 1
torch.manual_seed(seed)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader

# %%
dataset_filepath = 'dataset/weatherHistory.csv'
df = pd.read_csv(dataset_filepath)

# %%
univariate_df = df['Temperature (C)']
univariate_df.index = df['Formatted Date']

# %%
univariate_df
# Out:
# Formatted Date
# 2006-04-01 00:00:00.000 +0200     9.472222
# 2006-04-01 01:00:00.000 +0200     9.355556
# 2006-04-01 02:00:00.000 +0200     9.377778
# 2006-04-01 03:00:00.000 +0200     8.288889
# 2006-04-01 04:00:00.000 +0200     8.755556
#                                    ...
# 2016-09-09 19:00:00.000 +0200    26.016667
# 2016-09-09 20:00:00.000 +0200    24.583333
# 2016-09-09 21:00:00.000 +0200    22.038889
# 2016-09-09 22:00:00.000 +0200    21.522222
# 2016-09-09 23:00:00.000 +0200    20.438889
# Name: Temperature (C), Length: 96453, dtype: float64

# %%
input_size = 6
label_size = 1
offset = 1

def slicing_window(df, df_start_idx, df_end_idx, input_size, label_size, offset):
    features = []
    labels = []

    window_size = input_size + offset

    if df_end_idx == None:
        df_end_idx = len(df) - window_size

    for idx in range(df_start_idx, df_end_idx):
        feature_end_idx = idx + input_size
        label_start_idx = idx + window_size - label_size

        feature = df[idx:feature_end_idx]
        label = df[label_start_idx:(idx+window_size)]

        features.append(feature)
        labels.append(label)

    features = np.expand_dims(np.array(features), -1)
    labels = np.array(labels)

    return features, labels

# %%
dataset_length = len(univariate_df)
train_size = 0.7
val_size = 0.2
train_end_idx = int(train_size * dataset_length)
val_end_idx = int(val_size * dataset_length) + train_end_idx

X_train, y_train = slicing_window(
    univariate_df,
    df_start_idx=0,
    df_end_idx=train_end_idx,
    input_size=input_size,
    label_size=label_size,
    offset=offset
)

X_val, y_val = slicing_window(
    univariate_df,
    df_start_idx=train_end_idx,
    df_end_idx=val_end_idx,
    input_size=input_size,
    label_size=label_size,
    offset=offset
)

X_test, y_test = slicing_window(
    univariate_df,
    df_start_idx=val_end_idx,
    df_end_idx=None,
    input_size=input_size,
    label_size=label_size,
    offset=offset
)

# %%
class WeatherForecast(Dataset):
    def __init__(
        self,
        X, y,
        transform=None
    ):
        self.X = X
        self.y = y
        self.transform = transform

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        X = self.X[idx]
        y = self.y[idx]

        if self.transform:
            X = self.transform(X)

        X = torch.tensor(X, dtype=torch.float32)
        y = torch.tensor(y, dtype=torch.float32)

        return X, y

# %%
train_dataset = WeatherForecast(
    X_train, y_train
)
val_dataset = WeatherForecast(
    X_val, y_val
)
test_dataset = WeatherForecast(
    X_test, y_test
)

# %%
train_batch_size = 128
test_batch_size = 8

train_loader = DataLoader(
    train_dataset,
    batch_size=train_batch_size,
    shuffle=True
)
val_loader = DataLoader(
    val_dataset,
    batch_size=test_batch_size,
    shuffle=False
)
test_loader = DataLoader(
    test_dataset,
    batch_size=test_batch_size,
    shuffle=False
)

# %%
class WeatherForecastor(nn.Module):
    def __init__(
        self, embedding_dim, hidden_size,
        n_layers, dropout_prob
    ):
        super(WeatherForecastor, self).__init__()
        self.bilstm = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=hidden_size,
            num_layers=n_layers,
            batch_first=True,
            bidirectional=True
        )
        self.norm = nn.LayerNorm(hidden_size * 2)

        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(hidden_size * 2, 1)

    def forward(self, x):
        x, hn = self.bilstm(x)
        x = x[:, -1, :]
        x = self.norm(x)
        x = self.dropout(x)
        x = self.fc(x)

        return x

# %%
embedding_dim = 1
hidden_size = 8
n_layers = 3
dropout_prob = 0.2
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = WeatherForecastor(
    embedding_dim=embedding_dim,
    hidden_size=hidden_size,
    n_layers=n_layers,
    dropout_prob=dropout_prob
).to(device)

# %%
model.eval()

dummy_tensor = torch.randn((1, 6, 1)).to(device)

with torch.no_grad():
    output = model(dummy_tensor)

print('Output shape:', output.shape)
# Out:
# Output shape: torch.Size([1, 1])

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()

    losses = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            losses.append(loss.item())

    loss = sum(losses) / len(losses)

    return loss

# %%
def fit(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs
):
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        batch_train_losses = []

        model.train()
        for idx, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            batch_train_losses.append(loss.item())

        train_loss = sum(batch_train_losses) / len(batch_train_losses)
        train_losses.append(train_loss)

        val_loss = evaluate(
            model, val_loader,
            criterion, device
        )
        val_losses.append(val_loss)

        print(f'EPOCH {epoch + 1}:\tTrain loss: {train_loss:.4f}\tVal loss: {val_loss:.4f}')

    return train_losses, val_losses

# %%
lr = 1e-3
epochs = 50

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=lr
)

# %%
train_losses, val_losses = fit(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs
)
# Out:
# EPOCH 1:	Train loss: 92.6243	Val loss: 14.0833
# EPOCH 2:	Train loss: 12.7911	Val loss: 3.0268
# EPOCH 3:	Train loss: 7.6827	Val loss: 1.9436
# EPOCH 4:	Train loss: 6.5624	Val loss: 1.7592
# EPOCH 5:	Train loss: 6.2790	Val loss: 1.7301
# EPOCH 6:	Train loss: 6.0481	Val loss: 1.5884
# EPOCH 7:	Train loss: 5.8908	Val loss: 1.5451
# EPOCH 8:	Train loss: 5.8514	Val loss: 1.4934
# EPOCH 9:	Train loss: 5.7077	Val loss: 1.6292
# EPOCH 10:	Train loss: 5.6500	Val loss: 1.5657
# EPOCH 11:	Train loss: 5.6126	Val loss: 1.5866
# EPOCH 12:	Train loss: 5.4210	Val loss: 1.5351
# EPOCH 13:	Train loss: 5.4245	Val loss: 1.5434
# EPOCH 14:	Train loss: 5.2945	Val loss: 1.5511
# EPOCH 15:	Train loss: 5.2006	Val loss: 1.5805
# EPOCH 16:	Train loss: 5.1738	Val loss: 1.8787
# EPOCH 17:	Train loss: 5.1734	Val loss: 1.6125
# EPOCH 18:	Train loss: 5.0209	Val loss: 1.5117
# EPOCH 19:	Train loss: 4.9475	Val loss: 1.5087
# EPOCH 20:	Train loss: 4.9410	Val loss: 1.5314
# EPOCH 21:	Train loss: 4.8342	Val loss: 1.5634
# EPOCH 22:	Train loss: 4.7720	Val loss: 1.8157
# EPOCH 23:	Train loss: 4.7448	Val loss: 1.5353
# EPOCH 24:	Train loss: 4.7264	Val loss: 1.5096
# EPOCH 25:	Train loss: 4.5841	Val loss: 1.5455
# EPOCH 26:	Train loss: 4.5533	Val loss: 1.5287
# EPOCH 27:	Train loss: 4.5176	Val loss: 1.4793
# EPOCH 28:	Train loss: 4.4537	Val loss: 1.5491
# EPOCH 29:	Train loss: 4.3740	Val loss: 1.7338
# EPOCH 30:	Train loss: 4.3965	Val loss: 1.4688
# EPOCH 31:	Train loss: 4.3198	Val loss: 1.5460
# EPOCH 32:	Train loss: 4.2870	Val loss: 1.4608
# EPOCH 33:	Train loss: 4.2819	Val loss: 1.4885
# EPOCH 34:	Train loss: 4.1912	Val loss: 1.5792
# EPOCH 35:	Train loss: 4.2117	Val loss: 1.5609
# EPOCH 36:	Train loss: 4.1634	Val loss: 1.5612
# EPOCH 37:	Train loss: 4.0496	Val loss: 1.5275
# EPOCH 38:	Train loss: 4.1041	Val loss: 1.6337
# EPOCH 39:	Train loss: 4.0574	Val loss: 1.5047
# EPOCH 40:	Train loss: 4.0240	Val loss: 1.4724
# EPOCH 41:	Train loss: 4.0147	Val loss: 1.6028
# EPOCH 42:	Train loss: 3.9767	Val loss: 1.4781
# EPOCH 43:	Train loss: 3.9726	Val loss: 1.5279
# EPOCH 44:	Train loss: 3.9384	Val loss: 1.4547
# EPOCH 45:	Train loss: 3.9345	Val loss: 1.4630
# EPOCH 46:	Train loss: 3.8911	Val loss: 1.5259
# EPOCH 47:	Train loss: 3.8806	Val loss: 1.4654
# EPOCH 48:	Train loss: 3.8964	Val loss: 1.5032
# EPOCH 49:	Train loss: 3.8331	Val loss: 1.4518
# EPOCH 50:	Train loss: 3.8248	Val loss: 1.4504

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].plot(train_losses)
ax[0].set_title('Training Loss')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[1].plot(val_losses, color='orange')
ax[1].set_title('Val Loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
plt.show()

# %%
val_loss = evaluate(
    model,
    val_loader,
    criterion,
    device
)
test_loss = evaluate(
    model,
    test_loader,
    criterion,
    device
)

print('Evaluation on val/test dataset')
print('Val loss: ', val_loss)
print('Test loss: ', test_loss)
# Out:
# Evaluation on val/test dataset
# Val loss:  1.4503601154236812
# Test loss:  1.2383338033488307

# %%
def plot_difference(y, pred):
    plt.figure(figsize=(20, 6))
    times = range(len(y))
    y_to_plot = y.flatten()
    pred_to_plot = pred.flatten()

    plt.plot(times, y_to_plot, color='steelblue', marker='o', label='True value')
    plt.plot(times, pred_to_plot, color='orangered', marker='X', label='Prediction')

    plt.title('Temperature in every hours')
    plt.xlabel('Hour')
    plt.ylabel('Temperature (C)')
    plt.legend()
    plt.show()

inputs = torch.tensor(X_test[:100], dtype=torch.float32).to(device)
model.eval()
with torch.no_grad():
    outputs = model(inputs).detach().cpu().numpy()
plot_difference(y_test[:100], outputs)
